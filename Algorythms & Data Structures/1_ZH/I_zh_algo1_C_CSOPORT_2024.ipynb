# %% [markdown]
# #Adatszerkezetek és algoritmusok gyakorlat
# #I. Zárthelyi dolgozat C CSOPORT, 24 pont
#
# ###Programozási nyelv: C# vagy Python
# ##Python esetén
# ####Google Colab neve: NÉV_NEPTUNKÓD
# ####Fájl-> Másolat készítése a Drive-on vagy Fájl->Mentés!
# ###Megosztás:
# ####Megosztás személyekkel és csoportokkal: kovacs.adam.eke@gmail.com
# ####Vagy
# ####Link lekérése (szerkesztő) -> Link másolatát emailben küldje el: kovacs.adam.eke@gmail.com
#
# ##C# esetén
# ####Fájl neve: NÉV_NEPTUNKÓD
# ####Majd a fájlt tömörítse be!
# ####Saját Google Drive mappába töltse fel a tömörített mapát és az alábbi email címre küldje el: kovacs.adam.eke@gmail.com

# %% [markdown]
# #1. feladat 4 pont
# Írjon algoritmust, amely az a és b pozitív egészek legnagyobb közös
# osztóját számítja ki az euklideszi algoritmus alapján.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2. feladat 3 pont
# Írjon algoritmust, amely megkeresi és kiíratja egy négyzetes mátrix mellékátló alatti elemei közül a legkisebb értékű elemet!

# %% [markdown]
# #3. feladat (2+2) 4 pont
# Az összegzés tételének alkalmazásával számítsuk ki az alábbi kifejezések értékét,  feltételezve, hogy elegendő csak véges sok tagot figyelembe vennünk:
#
# Gyökvonáshoz használja a ```math.sqrt()``` függvényt!
#
# * ![feladat3a.png](data:image/png;base64,...)
# * ![image.png](data:image/png;base64,...)

# %%
#Futtassa le a cellát a math könyvtár használatához!
import math

# %% [markdown]
# #4. feladat 4 pont
# Írjon algoritmust, amely kiválogatja egy listába a 44-nél nagyobb, de 111-nél kisebb néggyel osztható számokat számokat!
#
# Az algoritmus a kiválogatott elemek számával térjen vissza!
#
# Az algoritmus ```print()``` függvény segítségével írassa ki az eredeti lista elemeit, és alá a kiválogatott elemeket tartalmazó lista tartalmát!

# %% [markdown]
# #5. feladat 4 pont
# Adja meg annak az algoritmusnak a pszeudokódját, amely egy tetszőleges, egész számokat tartalmazó sorozat 5-tel osztható páratlan elemeinek darabszámát adja vissza!

# %%
""" Pszeudokód

"""

# %% [markdown]
# #6. feladat 5 pont
# Koordinátáival adott egy n elemű pontsorozat a síkban. Határozzuk meg, van-e olyan eleme, amely kívül esik egy adott r sugarú $O(x_0, y_0)$
# középpontú körön. A feladat megoldásához használja az eldöntés tételét!
# ![image.png](data:image/png;base64,...)
